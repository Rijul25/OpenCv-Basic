# %%
import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread("dog.jpg",0)

# %%
plt.imshow(img)
plt.show()

# %%
print(cv2)
# Out:
# <module 'cv2.cv2' from '/usr/local/lib/python3.7/site-packages/cv2/cv2.cpython-37m-darwin.so'>
